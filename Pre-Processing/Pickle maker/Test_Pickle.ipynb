# %%
import pickle
import gzip
import os

# %%
# Uncomment the file you need to check
# pickle_dest = "/Dataset/Pickles/excel_dataTest.pickle"
# pickle_dest = "/Dataset/Pickles/excel_dataVal.pickle"
# pickle_dest = "/Dataset/Pickles/excel_dataTrain.pickle"
pickle_dest = "/Dataset/Pickles/Sports_Dataset/0/excel_data.test"

# %%
# pickle_dest = os.getcwd() + pickle_dest

def view_gzip_pickle_file(file_path):
    try:
        with gzip.open(os.getcwd() + file_path, 'rb') as file:
            data = pickle.load(file)
            print("Contents of the gzip-compressed pickle file:")
            print(data)
            return data
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"Error: {e}")

# %%
# Example usage:
out = view_gzip_pickle_file(pickle_dest)
# Out:
# Contents of the gzip-compressed pickle file:
# [{'name': '70_127.00', 'signer': 'Signer01', 'gloss': 'A B C D E', 'text': 'He then holds a bottle of water up saying Agua which means water in Portuguese', 'sign': tensor([[ 0.0538, -0.1888,  0.0749,  ...,  0.0680, -0.1361, -0.1876],
#         [-0.0384, -0.1733,  0.2059,  ...,  0.0289, -0.0985, -0.1851],
#         [ 0.0464, -0.1855,  0.1020,  ...,  0.2252, -0.1358, -0.2326],
#         ...,
#         [-0.0153, -0.1928,  0.3172,  ...,  0.3566,  0.6261, -0.2269],
#         [ 0.0089, -0.2077,  0.3099,  ...,  0.4236,  0.5677, -0.2279],
#         [ 0.0315, -0.2008,  0.3802,  ...,  0.3598,  0.5485, -0.2094]])}, {'name': '60_10.00', 'signer': 'Signer01', 'gloss': 'A B C D E', 'text': 'Shane is from Australia he however had a two-storey holiday villa in Thailand', 'sign': tensor([[ 0.0196, -0.1329,  0.4904,  ...,  0.0983, -0.0622, -0.1788],
#         [ 0.0965, -0.1102,  0.4694,  ...,  0.1506,  0.0769,  0.0121],
# ...

# %%
out[2]['sign']
# Out:
# tensor([[-0.0729, -0.2215,  0.3999,  ...,  0.0172,  0.4583, -0.0396],
#         [-0.0868, -0.2248,  0.3594,  ...,  0.0213,  0.5454,  0.0006],
#         [-0.0727, -0.2269,  0.4035,  ..., -0.0036,  0.3501, -0.0251],
#         ...,
#         [-0.0355, -0.0624,  0.3269,  ...,  0.1961,  0.1433, -0.0274],
#         [-0.1388, -0.2190,  0.2612,  ...,  0.2408,  0.3394, -0.0227],
#         [-0.1212, -0.0892,  0.2947,  ...,  0.2099,  0.0725,  0.1928]])
